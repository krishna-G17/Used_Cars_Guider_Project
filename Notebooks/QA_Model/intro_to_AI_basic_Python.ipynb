# %%
x = 10
y = 20
if x == 10 and y == 20:
    print("both variables are what you want!")
# Out:
# both variables are what you want!

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
x = 100.0
type(x)
# Out:
# float

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
s = 123
float(s)
# Out:
# 123.0

# %%
s = 123.45
float(int(s))
# Out:
# 123.0

# %%
z=5j
type(z)
# Out:
# complex

# %%
w=8
w=w+1
w
# Out:
# 9

# %%
w+=1
w
# Out:
# 10

# %%
w+=2
w
# Out:
# 12

# %%
distance = float(input('How far did you run (in kilometers)? '))
minutes = int(input('How many minutes did you take? '))
pace = int(distance)/int(minutes)
print(f'You ran at a pace of {pace} kilometers per minute')
# Out:
# You ran at a pace of 0.08375 kilometers per minute

# %%
s = 'kndvsdvubsnkdvs'
print(len(s))
s[5]
x=10
print(f'x = {x}')
print(f'x = {x}, but x*2 = {x*2}')
# Out:
# 15
# x = 10
# x = 10, but x*2 = 20

# %%
pages = input('How many pages did you read')
minutes = input('How many minutes did it take ')
speed = int(distance)/int(minutes)
print(f'Your reading speed is {speed} pages per minute')
# Out:
# Your reading speed is 3.35 pages per minute

# %%
name = input('enter your name')
if name[-1] in 'aeiou':
    print(f'Your name ends with a vowel')
else:
    print(f'Your name ends with a consonant')
# Out:
# Your name ends with a consonant

# %%
name = input("enter your name")
index = input("enter a positive integer")
index = int(index)
if index<0:
    print(f'Your have entered a negative value')
elif index>=len(name):
    print(f'Your index is out of range, Max index is {len(name)-1}')
else:
    print(f'The character at index {index} is {name[index]}')
# Out:
# The character at index 3 is o
