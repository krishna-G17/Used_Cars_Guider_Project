# %% [markdown]
# # ANSWERS
# Enter all of your official answers to each question here. Questions 2-5 should be answered using **first touch attribution.**

# %% [markdown]
# ### Q1: What category of channel has the lowest cost per click?

# %% [markdown]
# #### Social Media

# %% [markdown]
# ### Q2: What are the top three campaigns in terms of number of sales generated by first touch attribution?

# %% [markdown]
# #### Sedan, Convertible, 25+

# %% [markdown]
# ### Q3: Which campaigns had the most month over month growth/decline in number of sales generated from Oct to Dec?

# %% [markdown]
# #### Top 3 Growing Campaigns: Truck
# #### Top 3 Growing Campaigns: Convertible

# %% [markdown]
# ### Q4: Which partner is the most cost efficient, i.e., has the lowest CAC

# %% [markdown]
# #### Debit Dharma

# %% [markdown]
# ### Q5: Which category of channel has the best ROI? The worst? (please reference ROI formula and profit calculation)

# %% [markdown]
# #### Best ROI Category: Finance Partnership with ROI of 2.43
# #### Worst ROI Category: Third Party Listing with ROI of 0.23

# %% [markdown]
# ### Q6: On average, how many different channels do customers interact with prior to locking a car?

# %% [markdown]
# #### 4

# %% [markdown]
# ### Q7: What percentage of sales don't have a click within 90 days prior to the conversion? How can you explain this?

# %% [markdown]
# #### 2.85%
#
# #### Reasons can be:
# ##### 1. Organic Traffic - website visitors through direct URL or Bookmark
# ##### 2. Slow Conversion - Genuine visitors coming after 90 days to purchase
# ##### 3. Anonymous browsing user can track a car listing and purchase in one-go
# ##### 4. Tracking gaps - Marketing channels might have not been able to track user due to disabling cookies or using ad blockers

# %% [markdown]
# ### Q8: Based on what you know about channel performance, what recommendation would you give for re-allocating spend given we are increasing budget by 20% next year?

# %% [markdown]
# #### As the given data is limited to Q4 only, I was able to deduct only a vague picture or I can recommend for the same season (last four months).
#
# ### Observations
# #### 1. Two of the highest spends are returning less than 30% of investment.
# #### 2. Conversion Rates are observed best in December with a sharp fall in November.
# #### 3. Based on the correlation matrix, More sales transactions could bring in better ROI on conversions.
# #### 4. (Recomm) so it is advisable to look into channels with the potential for more sales transactions.
#
# ### Recommendations (by Channel)
# #### 1. Channels exhibiting high ROI with a significant sales volume should be the primary focus, alongside considering current inventory
# #####  a. Debit-Dharma (ROI: 2.43, 137 sales)
# #####  b. Search Engine - Bam - Sedan (ROI: 2.39, 91 sales)
# #####  c. Finance Partnership -Giving Vine (ROI: 2.17, 108 sales)
#
# #### 2. Re-evaluate underperforming channels and consider experimenting with potential channels of higher sales volume and moderate ROI
# #####  a. Third Party Listing-ManualBarter	 (ROI: 2.43, 137 sales)
# #####  b. Third Party Listing-RealTruck (ROI: 2.39, 91 sales)
#
# #### 3. Channels with Potential
# #####  a. Online Video-WeTube_25+ (ROI: 1.72, 85 sales)
# #####  b. Social Media-KnickKnack (ROI: 1.56, 47 sales)
#
# ### Recommendations (by Campaign)
# #### 1. Huge Potential for "25+" campaign over "convertible" campaign - (suggested investment) from Oct to Dec
#
#
# ### Recommendations (by Category)
# #### 1. "Third Party" investments can be diverted/distributed to experiment with promising "Finance Partnership" or "Online Video" advertising category.
