# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy as sa

# %%
df = pd.read_csv('DF_to_load_into_SSMS.csv')
# Out:
# C:\Users\golla\AppData\Local\Temp\ipykernel_16008\4058584163.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('DF_to_load_into_SSMS.csv')

# %%
len(df)
# Out:
# 355439

# %%
df.columns = df.columns.str.strip()

# %%
connection = sqlite3.connect('UCPP_test.db')
cursor = connection.cursor()

# %%
df.to_sql('used_cars', connection, if_exists='replace')
# Out:
# 355439

# %%
cursor.execute("select distinct Date from used_cars")

cursor.fetchall()
# Out:
# [('2024-02-12',),
#  ('2024-02-13',),
#  ('2024-03-22',),
#  ('2024-02-14',),
#  ('2024-02-16',),
#  ('2024-03-29',),
#  ('2024-02-17',),
#  ('2024-02-18',),
#  ('2024-02-19',),
#  ('2024-02-20',),
#  ('2024-02-21',),
#  ('2024-02-22',),
#  ('2024-02-23',),
#  ('2024-02-24',),
#  ('2024-02-25',),
#  ('2024-02-26',),
#  ('2024-02-27',),
#  ('2024-02-28',),
#  ('2024-02-29',),
#  ('2024-03-01',),
#  ('2024-03-02',),
#  ('2024-03-03',),
#  ('2024-03-04',),
#  ('2024-03-05',),
#  ('2024-03-06',),
#  ('2024-03-07',),
#  ('2024-03-08',),
#  ('2024-03-09',),
#  ('2024-03-10',),
#  ('2024-03-11',),
#  ('2024-03-12',),
#  ('2024-03-13',),
#  ('2024-03-14',),
#  ('2024-03-16',),
#  ('2024-03-17',),
#  ('2024-03-18',),
#  ('2024-03-23',),
#  ('2024-03-24',),
#  ('2025-03-25',),
#  ('2024-03-26',)]

# %%
table_name = 'used_cars'
query = f"SELECT * FROM {table_name}"

df = pd.read_sql_query(query, connection)

len(df)

# %%
# Assuming SQLAlchemy is installed
df = pd.read_sql_table(table_name, connection)

len(df)

# %%
connection.close()
